# %% [markdown]
# # <div style="color:#fff;display:fill;border-radius:10px;background-color:#004F98;text-align:center;letter-spacing:0.1px;overflow:hidden;padding:20px;color:white;overflow:hidden;margin:0;font-size:100%">Predict Football Match Winners || English Premier League</div>

# %% [markdown]
# ## <span style='color:#2E8BC0'> 0| Import Libraries</span>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## <span style='color:#2E8BC0'> 1| Load & Reading Dataset</span>

# %%
dataset = pd.read_csv("matches.csv")
df = dataset.copy()

# ==> Get top 5
df.head()
# Out:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result   gf   ga  ...  match report  notes    sh   sot  dist   fk   pk  \
# 0      L  0.0  1.0  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0
# 1      W  5.0  0.0  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0
# 2      W  5.0  0.0  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0
# 3      W  1.0  0.0  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0
# 4      D  0.0  0.0  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0
#
#   pkatt season             team
# 0   0.0   2022  Manchester City
# ...

# %%
df.shape
# Out:
# (1389, 28)

# %%
df = df.drop(columns='Unnamed: 0',axis=True)

# %%
df.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 1  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 2  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 3  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 4  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 0       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 1    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 2         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 3  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 4     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
# ==> Shape of Data(Rows, COlumns)
df.shape
# Out:
# (1389, 27)

# %%
# ==> Get Last 5 of Data
df.tail()
# Out:
#             date   time            comp         round  day venue result   gf  \
# 1384  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 1385  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 1386  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 1387  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 1388  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#        ga        opponent  ...  match report  notes    sh  sot  dist   fk  \
# 1384  4.0       Tottenham  ...  Match Report    NaN   8.0  1.0  17.4  0.0
# 1385  2.0  Crystal Palace  ...  Match Report    NaN   7.0  0.0  11.4  1.0
# 1386  0.0         Everton  ...  Match Report    NaN  10.0  3.0  17.0  0.0
# 1387  1.0   Newcastle Utd  ...  Match Report    NaN  11.0  1.0  16.0  1.0
# 1388  0.0         Burnley  ...  Match Report    NaN  12.0  3.0  17.0  0.0
#
#        pk pkatt  season              team
# ...

# %%
# ==> Get Columns Name
df.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %%
# ==> Get info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1389 entries, 0 to 1388
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1389 non-null   object
#  1   time          1389 non-null   object
#  2   comp          1389 non-null   object
#  3   round         1389 non-null   object
#  4   day           1389 non-null   object
#  5   venue         1389 non-null   object
#  6   result        1389 non-null   object
#  7   gf            1389 non-null   float64
#  8   ga            1389 non-null   float64
#  9   opponent      1389 non-null   object
#  10  xg            1389 non-null   float64
#  11  xga           1389 non-null   float64
#  12  poss          1389 non-null   float64
#  13  attendance    693 non-null    float64
#  14  captain       1389 non-null   object
#  15  formation     1389 non-null   object
#  16  referee       1389 non-null   object
#  17  match report  1389 non-null   object
# ...

# %%
# ==> Descriptive Statistics about dataset

df.describe()
# Out:
#                 gf           ga           xg          xga         poss  \
# count  1389.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean      1.335493     1.380850     1.304176     1.338445    49.702664
# std       1.274235     1.291049     0.767268     0.789360    12.401897
# min       0.000000     0.000000     0.000000     0.000000    18.000000
# 25%       0.000000     0.000000     0.700000     0.700000    40.000000
# 50%       1.000000     1.000000     1.200000     1.200000    50.000000
# 75%       2.000000     2.000000     1.800000     1.800000    59.000000
# max       9.000000     9.000000     4.600000     5.000000    82.000000
#
#          attendance  notes           sh          sot         dist  \
# count    693.000000    0.0  1389.000000  1389.000000  1388.000000
# mean   36089.963925    NaN    12.153348     4.041037    17.011527
# std    17797.991778    NaN     5.268876     2.403866     2.988364
# ...

# %%
df.describe(include=['O'])
# Out:
#               date   time            comp        round   day venue result  \
# count         1389   1389            1389         1389  1389  1389   1389
# unique         244     18               1           38     7     2      3
# top     2021-05-23  15:00  Premier League  Matchweek 1   Sat  Away      L
# freq            20    286            1389           39   551   695    548
#
#            opponent      captain formation         referee  match report  \
# count          1389         1389      1389            1389          1389
# unique           23           91        16              23             1
# top     Southampton  Hugo Lloris   4-2-3-1  Anthony Taylor  Match Report
# freq             71           70       344             100          1389
#
#                team
# count          1389
# unique           23
# top     Southampton
# freq             72

# %% [markdown]
# ## <span style='color:#2E8BC0'> 2| EDA ( Exploratory data analysis)</span>

# %%
dt = df['team'].value_counts()

# %%
dt
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
dt.plot(kind='bar', figsize=(12,6), color=sns.color_palette("magma"))
# Out:
# <AxesSubplot:>

# %%
df[df['team'] == 'Liverpool']
# Out:
#            date   time            comp         round  day venue result   gf  \
# 705  2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 706  2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 707  2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 708  2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 709  2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 710  2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 711  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 712  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 713  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 714  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 715  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
df['round'].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %% [markdown]
# ## <span style='color:#2E8BC0'> 3| Data Preprocessing (Cleaning Data)</span>

# %%
# ==> Know Datatype of Features
df.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
# ==> Converting date in df
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 1 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 2 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 3 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 4 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 0       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 1    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 2         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 3  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 4     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
df.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
# ==> change dtype of feature and oncodeing set
df['venue_Code'] = df['venue'].astype('category').cat.codes

# %%
df['opp_code'] = df['opponent'].astype('category').cat.codes

# %%
df['hour'] = df['time'].str.replace(":.+","",regex=True).astype('int')

# %%
df['day_code'] = df['date'].dt.dayofweek

# %%
df['target'] = (df['result']=="W").astype('int')

# %%
df
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 1    2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 2    2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 3    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 4    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1384 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 1385 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 1386 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 1387 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 1388 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
# ...

# %% [markdown]
# ## <span style='color:#2E8BC0'> 4| Split Train and Test Data </span>

# %%
train = df[df["date"] < '2022-01-01']

# %%
test = df[df["date"] > '2022-01-01']

# %%
predictors = ["venue_Code", "opp_code", "hour", "day_code"]

# %% [markdown]
# ## <span style='color:#2E8BC0'> 5| Build Model </span>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = df.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#           date   time            comp         round  day venue result   gf  \
# 632 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 633 2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 634 2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 635 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 636 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 28  2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 29  2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 30  2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 31  2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 32  2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
# ...

# %%
matches_rolling = df.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                   date   time            comp         round  \
# team
# Arsenal                 898 2020-10-04  14:00  Premier League   Matchweek 4
#                         899 2020-10-17  17:30  Premier League   Matchweek 5
#                         900 2020-10-25  19:15  Premier League   Matchweek 6
#                         901 2020-11-01  16:30  Premier League   Matchweek 7
#                         902 2020-11-08  19:15  Premier League   Matchweek 8
# ...                                ...    ...             ...           ...
# Wolverhampton Wanderers 227 2022-03-13  14:00  Premier League  Matchweek 29
#                         228 2022-03-18  20:00  Premier League  Matchweek 30
#                         229 2022-04-02  15:00  Premier League  Matchweek 31
#                         230 2022-04-08  20:00  Premier League  Matchweek 32
#                         231 2022-04-24  14:00  Premier League  Matchweek 34
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#           date   time            comp         round  day venue result   gf  \
# 898 2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 899 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 900 2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 901 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 902 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 227 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 228 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 229 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 230 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 231 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 55       0          0 2022-01-23  Arsenal         Burnley      D
# 56       1          0 2022-02-10  Arsenal          Wolves      W
# 57       1          0 2022-02-19  Arsenal       Brentford      W
# 58       1          1 2022-02-24  Arsenal          Wolves      W
# 59       1          1 2022-03-06  Arsenal         Watford      W
# 60       1          1 2022-03-13  Arsenal  Leicester City      W
# 61       0          1 2022-03-16  Arsenal       Liverpool      L
# 62       1          0 2022-03-19  Arsenal     Aston Villa      W
# 63       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 64       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"} 
mapping = MissingDict(**map_values)
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    27
# 0    13
# Name: actual_x, dtype: int64
